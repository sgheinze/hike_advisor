# %%
import pandas as pd

# %%
columns = sorted(list(pd.read_pickle('column_names')))

# %%
hike_names = []
for hike_name in columns:
    hike_names.append({'name': hike_name})

# %%
hike_names
# Out:
# [{'name': 'Abalone Cove Trail'},
#  {'name': 'Ahwingna and Native Oak Loop Trail'},
#  {'name': 'Alamere Falls via Coast Trail from Palomarin Trailhead'},
#  {'name': 'Aliso Creek and Wood Canyon Loop Trail'},
#  {'name': 'Aliso Summit Trail'},
#  {'name': 'Alta Peak Trail'},
#  {'name': 'Alum Rock South Rim Trail'},
#  {'name': 'Amboy Crater'},
#  {'name': "Annie's Canyon via North Rios Trail"},
#  {'name': 'Ano Nuevo Point Trail'},
#  {'name': 'Antelope Loop Trail'},
#  {'name': 'Arch Rock Nature Trail'},
#  {'name': 'Arrowhead Pinacles Trail'},
#  {'name': 'Arroyo Pescadero and Deer Loop Trail'},
#  {'name': 'Arroyo, Old Spanish and Toyon Trail'},
#  {'name': 'Backbone Trail to Sandstone Peak [CLOSED]'},
#  {'name': 'Badwater Basin Salt Flats Trail'},
#  {'name': 'Bailey Canyon Trail to Jones Peak'},
#  {'name': 'Baldwin Hills Scenic Overlook Trail'},
#  {'name': 'Baldy Bowl Trail to Mount San Antonio'},
#  {'name': 'Baltimore Canyon Via Dawn Falls Trail Loop'},
# ...

# %%
pd.read_pickle('hike_data_filtered_190124')
# Out:
#                       Taft Point and The Fissures  \
#  Bill Friedman                                0.0
# $15 $40                                       0.0
# ** watson **                                  0.0
# 3IrinaAmira D.                                0.0
# @rafiky _resiii                               0.0
# A + K                                         0.0
# A G                                           0.0
# AURORA BANALES                                0.0
# Aaron Nelson                                  1.0
# Aaron Panik                                   0.0
# Abby B                                        0.0
# Abhi Raj                                      0.0
# Abigail Christine                             0.0
# Adam  Mattheus                                0.0
# Adam Hilliard                                 0.0
# Adam Lassak                                   0.0
# Adam Leibowitz                                0.0
# Adam Schultz                                  0.0
# ...
